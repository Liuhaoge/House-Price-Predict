# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 基本数据统计信息

# %%
train=pd.read_csv('./data.csv')

# %%
train.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.shape[0]
# Out:
# 1460

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
tmp=train.sort_values(by='SalePrice',ascending=False)  #按照saleprice排序，加上参数ascending=False表示降序排列
tmp.head(20)  #必须要定义一个tmp值，train.sort不会改变train的结构
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# ...

# %%
np.log(train['SalePrice']).describe()
# Out:
# count    1460.000000
# mean       12.024051
# std         0.399452
# min        10.460242
# 25%        11.775097
# 50%        12.001505
# 75%        12.273731
# max        13.534473
# Name: SalePrice, dtype: float64

# %%
# 输出每个属性的null个数
def count_Null(t):
    tmp=t.isnull().sum()
    print(tmp[tmp>0])
    print(tmp[tmp>0].shape)

count_Null(train)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# (19,)

# %% [markdown]
# ## 数据预处理

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   # 可以内嵌绘图，省掉plt.show()这一步
# Out:
# UsageError: unrecognized arguments: # 可以内嵌绘图，省掉plt.show()这一步

# %% [markdown]
# ### 数据列的填充
# numercial型数据的填充

# %%
train1=train  #复制一个数据集，防止原数据集被破坏

# %%
train1.mean()
train1.median()
# Out:
# Id                  730.5
# MSSubClass           50.0
# LotFrontage          69.0
# LotArea            9478.5
# OverallQual           6.0
# OverallCond           5.0
# YearBuilt          1973.0
# YearRemodAdd       1994.0
# MasVnrArea            0.0
# BsmtFinSF1          383.5
# BsmtFinSF2            0.0
# BsmtUnfSF           477.5
# TotalBsmtSF         991.5
# 1stFlrSF           1087.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              0.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          6.0
# Fireplaces            1.0
# GarageYrBlt        1980.0
# GarageCars            2.0
# GarageArea          480.0
# WoodDeckSF            0.0
# OpenPorchSF          25.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# ...

# %%
train1=train1.fillna(train1.mean())  # 使用平均值填充

count_Null(train1)  #有三个属性是连续的，已被填充
# Out:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# (16,)

# %% [markdown]
# catergorial型数据填充：空值填充，高频填充，通过其他特征的关系填充

# %%
# 用None填充空缺的离散值
train1=train1.fillna("None")  #一定要进行赋值操作，否则只会生成一个结果并不改变原值

# %%
count_Null(train1)
# Out:
# Series([], dtype: int64)
# (0,)

# %% [markdown]
# ## 训练集的制作

# %%
y=train1['SalePrice']  #取出训练标签
train1=train1.drop(['Id','SalePrice'], axis=1)  #去掉这两列, axis=1表示操控列，=0表示操控行

# %%
X=pd.get_dummies(train1).reset_index(drop=True)  #one_hot化，列数会扩充,为了计算欧式距离更准确
X.shape
# Out:
# (1460, 303)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error #使用均方差函数，衡量数据集的好坏
from sklearn.model_selection import train_test_split  #数据集切分

# %%
matrix= xgb.DMatrix(data=X, label=y)

# 切分数据集，80%训练，20%测试
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %% [markdown]
# ## 训练、生成模型

# %%
    #生成一个回归器对象： 线性函数拟合，列采样率（特征选择率）0.4，学习率0.01，树分裂最深8层，L1正则化系数10，子树的数量100（也是深度），每棵树的样本采样率0.7
xg_reg=xgb.XGBRegressor(objective='reg:linear',colsample_bytree=0.4,learning_rate=0.01,max_depth=8,alpha=10,n_estimators=100,subsample=0.7)
                      #objective有linear和logistic。                                             lambda是L2参数

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=8, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.7)

# %% [markdown]
# ## 测评过程：预测值与标签值的误差计算

# %%
pred=xg_reg.predict(X_test)

# %%
rmse=np.sqrt(mean_squared_error(y_test,pred))
rmse
# Out:
# 82125.5382810847

# %%
logrmse=np.sqrt(mean_squared_error(np.log(y_test),np.log(pred)))
logrmse
# Out:
# 0.4757173539197088

# %% [markdown]
# ### 调参：
#     estimator适当增大、colsample_bytree和learning_rate适当减小、

# %%
xgb.plot_importance(xg_reg)
plt.show()

# %% [markdown]
# ## 数据的挖掘与分析
# 1. 数据属性与target的相关性
# 2. 数据属性之间的相关性[correlation 协方差]
# 3. 缺失属性的填充
# 4. 构造属性

# %%
train.corr()  #属性之间的相关矩阵
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corr=train.corr()['SalePrice']     #各属性与房价的相关性
#正相关特征
corr[corr>0.5]
# Out:
# OverallQual     0.790982
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# GrLivArea       0.708624
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# GarageCars      0.640409
# GarageArea      0.623431
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
#负相关特征
corr[corr<0]
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# OverallCond     -0.077856
# BsmtFinSF2      -0.011378
# LowQualFinSF    -0.025606
# BsmtHalfBath    -0.016844
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MiscVal         -0.021190
# YrSold          -0.028923
# Name: SalePrice, dtype: float64

# %%
from matplotlib import cm

#使用HeatMap进行协方差可视化
plt.figure(figsize=(30,30))
sns.heatmap(train.corr(),linewidth=0.01,square=True,cmap=cm.Blues,annot=True)

# %% [markdown]
# ##### 观察相关性比较强的特征与房价的关系

# %%
# 整体装修水平与每个层次平均房价的关系，按照装修水平降序排列。
train[['OverallQual','SalePrice']].groupby(['OverallQual']).mean().sort_values(by='OverallQual',ascending=False).plot.bar(color='#78A6D9')

# %%
# 属性之间的关系，车库面积与停车数正相关
train[['GarageCars','GarageArea']].groupby(['GarageCars']).mean().plot.bar(color='#324659')

# %%
np.corrcoef(train['GarageCars'],train['GarageArea']) # 两个特征的协方差矩阵
# Out:
# array([[1.        , 0.88247541],
#        [0.88247541, 1.        ]])

# %% [markdown]
# #### 分析房价的正相关特征
# 1. 画出相关性的图  2.画出正相关的图  3.查看散点来佐证相关性  4.决定要去掉的列

# %%
# 房价的所有强正相关特征、负相关特征 及全部特征
plt.figure(1)

plt.subplot(321)
corr[corr>0.5].sort_values().plot.bar(color='Blue')
plt.subplot(322)
corr[corr<0].sort_values().plot.bar(color='red')

plt.subplot(313)
corr.sort_values().plot.bar(color='Black')

# %%
# 散点图查看影响趋势
plt.scatter(train['OverallQual'],train['SalePrice'])

# %%
# 带回归的散点图
sns.lmplot('OverallQual','SalePrice',data=train)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 蜂巢图
sns.swarmplot('OverallQual','SalePrice',data=train)

# %%
# 箱线图
sns.boxplot('OverallQual','SalePrice',data=train)

# %% [markdown]
# ## 对缺失值进行合理的重新填充

# %%
tmp=train.isnull().sum()
tmp[tmp>0].sort_values(ascending=False).plot.bar(color='#548F6D')

# %% [markdown]
# ##### LotFrontage的填充 （住宅面积）

# %%
# 思路一:计算每个房子所属的Neighborhood的均值/中位数来填充
sns.barplot(train["LotFrontage"],train['Neighborhood'])  # 黑线代表置信区间

# %%
lot_medians=train.groupby('Neighborhood')['LotFrontage'].median()  #求得每个小区的面积平均数
Null_Lot=train[train['LotFrontage'].isnull()]['Neighborhood']  #每个面积为空值的房子所属的小区

#空值填充过程: 使用了思路二来填充，所以这一句没执行
# train['LotFrontage'].isnull()= lot_medians[Null_Lot]

# %%
# 思路二：通过LotArea计算出LotFrontage
train['LotFrontage'].corr(np.sqrt(train['LotArea']))
# Out:
# 0.6020022167939361

# %%
# 构造新属性
train['SqrtLotArea']=np.sqrt(train['LotArea'])
plt.scatter(train['SqrtLotArea'],train['LotFrontage'],edgecolors='#000000')

# %%
sns.jointplot('SqrtLotArea','LotFrontage',data=train,edgecolors='#000000')

# %%
filter=train['LotFrontage'].isnull()
train.LotFrontage[filter]=0.6*train.SqrtLotArea[filter]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### MasVnrType和MasVnrArea的填充  （大理石铺砖的类型）

# %%
sns.jointplot(train['MasVnrArea'],train['SalePrice'],edgecolors='#000000')
# 可见MasVnrArea与房价相关程度很低

# %%
sns.boxplot("MasVnrType","SalePrice",data=train)
# 可见MasVnrType与房价相关程度也很低

# %%
train[train.MasVnrType=='None'][['MasVnrArea','MasVnrType']]
# Type中有大量的空值，同时Type为空的Area也是零
# 说明type为None的房子根本没有用砖石填充，也就说明这两个属性都不重要
# Out:
#       MasVnrArea MasVnrType
# 1            0.0       None
# 3            0.0       None
# 5            0.0       None
# 8            0.0       None
# 9            0.0       None
# 10           0.0       None
# 12           0.0       None
# 15           0.0       None
# 17           0.0       None
# 18           0.0       None
# 19           0.0       None
# 21           0.0       None
# 23           0.0       None
# 24           0.0       None
# 26           0.0       None
# 28           0.0       None
# 29           0.0       None
# 30           0.0       None
# 31           0.0       None
# 32           0.0       None
# 33           0.0       None
# 36           0.0       None
# 38           0.0       None
# 39           0.0       None
# 41           0.0       None
# 42           0.0       None
# 43           0.0       None
# 44           0.0       None
# 46           0.0       None
# 47           0.0       None
# ...          ...        ...
# 1407         0.0       None
# ...

# %%
sns.lmplot('MasVnrArea','SalePrice',hue='MasVnrType',data=train)  
# 通过Type聚类，对每一类作回归（hue表示聚类），可以验证这两个属性是无关的

# %%
# 所以就用0填充Area，用None填充Type
filter=train['MasVnrArea'].isnull()
train.MasVnrArea[filter]=0.0

filter=train['MasVnrType'].isnull()
train.MasVnrType[filter]='None'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### Electrical的填充 （电气种类）

# %%
train.groupby(['Electrical']).count()
# Electrical列只有一个空值，而SBrkr频率是最高的，使用高频填充
# Out:
#               Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# Electrical
# FuseA         94          94        94           94       94      94     12
# FuseF         27          27        27           27       27      27      4
# FuseP          3           3         3            3        3       3      2
# Mix            1           1         1            1        1       1      0
# SBrkr       1334        1334      1334         1334     1334    1334     73
#
#             LotShape  LandContour  Utilities     ...       PoolQC  Fence  \
# Electrical                                       ...
# FuseA             94           94         94     ...            0     23
# FuseF             27           27         27     ...            0      2
# FuseP              3            3          3     ...            0      0
# Mix                1            1          1     ...            0      0
# SBrkr           1334         1334       1334     ...            7    256
#
# ...

# %%
filter=train['Electrical'].isnull()
train['Electrical'][filter]=train['Electrical'].mode()[0]  
# 使用众数填充，.mode()返回一个单元素的数组，[0]取出‘SBrkr’
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### Alley填充 (临近小巷类型)

# %%
train['Alley'].value_counts()  #存在大量空值
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
sns.stripplot(train['Alley'],train['SalePrice'])  #房价与小巷也没什么关系

# %%
#所以用None来填充
train['Alley']=train['Alley'].fillna('None')

# %% [markdown]
# ##### BaseMent 群填充  （地下室的所有属性）

# %%
sns.jointplot(train['TotalBsmtSF'],train['SalePrice'])
# 可见地下室整体质量和房价有很高相关性

# %%
basement_cols=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','BsmtFinSF1','BsmtFinSF2','TotalBsmtSF']
print(train[basement_cols][train['BsmtQual'].isnull()==True])
# 可见质量空缺的地下室，评分也为零，说明其根本没有地下室，所以将所有的空缺填充为'None'
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  \
# 17        NaN      NaN          NaN          NaN          NaN           0
# 39        NaN      NaN          NaN          NaN          NaN           0
# 90        NaN      NaN          NaN          NaN          NaN           0
# 102       NaN      NaN          NaN          NaN          NaN           0
# 156       NaN      NaN          NaN          NaN          NaN           0
# 182       NaN      NaN          NaN          NaN          NaN           0
# 259       NaN      NaN          NaN          NaN          NaN           0
# 342       NaN      NaN          NaN          NaN          NaN           0
# 362       NaN      NaN          NaN          NaN          NaN           0
# 371       NaN      NaN          NaN          NaN          NaN           0
# 392       NaN      NaN          NaN          NaN          NaN           0
# 520       NaN      NaN          NaN          NaN          NaN           0
# ...

# %%
#前五个是离散项，用None来填充，后三个是连续项不能填充None，就让其保持为0
for col in basement_cols[0:5]: 
    train[col]=train[col].fillna('None')

# %% [markdown]
# ##### FirePlace填充

# %%
sns.lmplot("Fireplaces","SalePrice",data=train,hue="FireplaceQu")
# 回归线基本趋于平，影响不大

# %%
sns.factorplot("Fireplaces","SalePrice",data=train,hue="FireplaceQu")
# 影响因子图来验证，竖线表示置信区间，确实影响不大
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
train[train['FireplaceQu'].isnull()]['Fireplaces'] 
# 可以看到着火点质量空缺的房子其实没有着火点，所以用'None'填充
# Out:
# Series([], Name: Fireplaces, dtype: int64)

# %%
train['FireplaceQu']=train['FireplaceQu'].fillna('None')

# %% [markdown]
# ##### Garage群填充

# %%
sns.distplot(train['GarageArea'],color='#444499',kde=True)
# 车库面积的分布基本为正态

# %%
sns.jointplot(train['GarageArea'],train['SalePrice'])
# 车库面积与房价强相关

# %%
sns.violinplot(train['GarageCars'],train['SalePrice'])
# 中位数呈偏态分布，但波动很大，应该受到市区还是郊区的影响

# %%
# 同地下室一样，车库各个属性为空时，车库面积为0，说明根本没有车库，用None填充
garage_cols=['GarageType','GarageQual','GarageCond','GarageYrBlt','GarageFinish','GarageCars','GarageArea']
train[garage_cols][train['GarageType'].isnull()]
# Out:
#      GarageType GarageQual GarageCond  GarageYrBlt GarageFinish  GarageCars  \
# 39          NaN        NaN        NaN          NaN          NaN           0
# 48          NaN        NaN        NaN          NaN          NaN           0
# 78          NaN        NaN        NaN          NaN          NaN           0
# 88          NaN        NaN        NaN          NaN          NaN           0
# 89          NaN        NaN        NaN          NaN          NaN           0
# 99          NaN        NaN        NaN          NaN          NaN           0
# 108         NaN        NaN        NaN          NaN          NaN           0
# 125         NaN        NaN        NaN          NaN          NaN           0
# 127         NaN        NaN        NaN          NaN          NaN           0
# 140         NaN        NaN        NaN          NaN          NaN           0
# 148         NaN        NaN        NaN          NaN          NaN           0
# ...

# %%
# 如果是离散型变量填充上None，连续变量（GarageYrBlt）填充为0
for col in garage_cols:
    if train[col].dtype==np.object:
        train[col]=train[col].fillna('None')
    else:
        train[col]=train[col].fillna(0.0)

# %%
train['GarageYrBlt'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ##### PoolArea填充

# %%
sns.distplot(train['PoolArea'],color='#444499',kde=True)
# 基本都没有游泳池

# %%
train[['PoolQC','PoolArea']][train['PoolQC'].isnull()]
# PoolQC为空就是没有游泳池
# Out:
#      PoolQC  PoolArea
# 0       NaN         0
# 1       NaN         0
# 2       NaN         0
# 3       NaN         0
# 4       NaN         0
# 5       NaN         0
# 6       NaN         0
# 7       NaN         0
# 8       NaN         0
# 9       NaN         0
# 10      NaN         0
# 11      NaN         0
# 12      NaN         0
# 13      NaN         0
# 14      NaN         0
# 15      NaN         0
# 16      NaN         0
# 17      NaN         0
# 18      NaN         0
# 19      NaN         0
# 20      NaN         0
# 21      NaN         0
# 22      NaN         0
# 23      NaN         0
# 24      NaN         0
# 25      NaN         0
# 26      NaN         0
# 27      NaN         0
# 28      NaN         0
# 29      NaN         0
# ...     ...       ...
# 1430    NaN         0
# 1431    NaN         0
# 1432    NaN         0
# 1433    NaN         0
# 1434    NaN         0
# 1435    NaN         0
# 1436    NaN         0
# 1437    NaN         0
# 1438    NaN         0
# ...

# %%
train.PoolQC=train.PoolQC.fillna('None')

# %% [markdown]
# ##### Fence（围栏）和MiscFeature（其他特征）填充

# %%
sns.violinplot(train['Fence'],train['SalePrice'],color='#55CC66')
sns.violinplot(train['MiscFeature'],train['SalePrice'],color='#665588')
# 这两个属性跟房价关系都不大，中位数差不多

# %%
train['Fence']=train['Fence'].fillna('None')
train['MiscFeature']=train['MiscFeature'].fillna('None')

# %%
train[train.isnull().sum()>0]   # 报错说明没有空值了
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-78-a6187f312a1e> in <module>
# ----> 1 train[train.isnull().sum()>0]   # 报错说明没有空值了
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_array(self, key)
# ...

# %% [markdown]
# ## 机器学习算法套装！！

# %%
# 数据集的准备
y=train['SalePrice']
train1=train.drop(['Id','SalePrice'],axis=1)
X=pd.get_dummies(train1).reset_index(drop=True) # one_hot

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %%
# 均方根误差评测函数
def benchmark(model,testset,label):
    pred=model.predict(testset)
    if pred[pred<0].shape[0]>0:  #异常处理，均方差不可能小于零
        print("Neg Value")
        return -1
    lrmse=np.sqrt(mean_squared_error(np.log(y_test),np.log(pred)))
    return lrmse

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()
lm.fit(X_train,y_train)
benchmark(lm,X_test,y_test)
# Out:
# 0.1262780962215784

# %%
# pipeline将函数进行首尾相接的串行化组装，能一次性串行执行包含的所有函数
# preprocessing包含集中数据预处理的方法,将尺度单位不同的特征归一化，提高精度，包含以下几种：
#                StandardScaler,MinMaxScaler,RobustScaler,Normalizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler

lmmodel=make_pipeline(RobustScaler(),lm).fit(X_train,y_train)
benchmark(lmmodel,X_test,y_test)
# Out:
# 0.1262780962215616

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.model_selection import KFold # 交叉验证的拆分器
from sklearn.linear_model import RidgeCV

# %%
kfolds=KFold(n_splits=10,shuffle=True,random_state=123) # 拆分成十份进行交叉验证，shuffle表示打乱顺序

# %%
# 1. 手动寻找最优过程：循环传入一堆正则化参数alphas，从中挑选最优的一个值
def ridge_train_test(alpha):                      #cv传入交叉验证的值
    ridge_model=make_pipeline(RobustScaler(),RidgeCV(alphas=[alpha],cv=kfolds)).fit(X_train,y_train)
    lrmse=benchmark(ridge_model,X_test,y_test)
    return lrmse

r_alphas1=np.logspace(-10,2,100)  # logspace表示从10的-10次方到2次方，中间分成100个数
r_alphas2=np.logspace(-10,5,100)  # 所有可能的正则化参数

scores1=[]
scores2=[]
for k in r_alphas1:
    scores1.append(ridge_train_test(k))
    
for k in r_alphas2:
    scores2.append(ridge_train_test(k))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.995254e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.035128e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.002210e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.700582e-19
# ...

# %%
plt.figure(1)
plt.subplot(211)
plt.plot(r_alphas1,scores1)
plt.subplot(212)
plt.plot(r_alphas2,scores2)
#通过不同的alpha参数取值做出的误差图，可见alpha趋近于零效果比较好，趋近100时效果最好，但在往后效果就变差了

# %%
scores1[99]  # alpha=100最好
# Out:
# 0.12385966794851838

# %%
# 2. 岭回归的自动寻找最优过程，直接把数组作为alphas输入，回归函数会直接找到最优解
ridge_model2=make_pipeline(RobustScaler(),RidgeCV(alphas=r_alphas1,cv=kfolds)).fit(X_train,y_train)
benchmark(ridge_model2,X_test,y_test)
# 但由于迭代有随机性的原因，找到的还不如alpha=100
# Out:
# 0.1254495213659261

# %%
ridge_model2.steps[1][1].alpha_   # 自动找到43最好
# Out:
# 43.287612810830616

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import LassoCV

r_alphas = [0.00005, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]

lasso_model=make_pipeline(RobustScaler(),LassoCV(alphas=r_alphas,random_state=142,cv=kfolds))
lasso_model.fit(X_train,y_train)

benchmark(lasso_model,X_test,y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
scores=lasso_model.steps[1][1].mse_path_    # 最佳参数在迭代过程中的十折曲线，因为KFold=10
plt.plot(r_alphas,scores,label='Lasso')

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.linear_model import ElasticNetCV

e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

elastic_cv=make_pipeline(RobustScaler(),ElasticNetCV(alphas=e_alphas,cv=kfolds,l1_ratio=e_l1ratio))
elastic_cv.fit(X_train,y_train)

benchmark(elastic_cv,X_test,y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %% [markdown]
# ### XGBoost

# %%
matrix=xgb.DMatrix(data=X_train,label=y_train)  # DMatrix是xgb的数据结构，每次使用都要导入

xgb_reg=xgb.XGBRegressor(objective='reg:linear',colsample_bytree=0.7,learning_rate=0.01,max_depth=3,n_estimators=3460,subsample=0.7,reg_alpha=0.00006,gamma=0,nthread=6,scale_pos_weight=1,seed=27)
#新参数：                                                                                                                           正则化项、生成子树的最小损失、6线并行计算、正负平衡参数、随即种子数
xgb_reg.fit(X_train,y_train)

benchmark(xgb_reg,X_test,y_test)
# Out:
# 0.10220848661729656

# %% [markdown]
# ### SVR

# %%
from sklearn import svm
# C越大，步长越慢； gamma是核函数超参；  epsilon是正则系数
svr_model=svm.SVR(C=10000000,gamma=1e-8,epsilon=0.2)

svr_model.fit(X_train,y_train)

benchmark(svr_model,X_test,y_test)
#效果不好，不加入集成了
# Out:
# 0.18626673607006092

# %% [markdown]
# ### Stacking 集成模型

# %%
from mlxtend.regressor import StackingCVRegressor
# 使用交叉验证的原理，通过使用底层的预测作为上层预测的特征。 或在KFold中用每一组的验证集构成上层算法的训练集。X

# %%
# 底层模型：ridge_model2，lasso_model,elastic_cv,xgb_reg

stack_gen=StackingCVRegressor(regressors=(ridge_model2,lasso_model,elastic_cv,xgb_reg),# 底层算法
                              meta_regressor=xgb_reg,# 上层算法
                              use_features_in_secondary=True) # 将底层的预测值和特征同时考虑

stackX=np.array(X_train) # stack要用array数据结构
stacky=np.array(y_train)

stack_gen.fit(stackX,stacky)

benchmark(stack_gen,np.array(X_test),np.array(y_test))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.745665e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.597381e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.520039e-19
#   overwrite_a=True).T
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.718697e-19
# ...

# %% [markdown]
# ## 特征工程

# %%
def TestDataSet(train):
    y=train['SalePrice']
    X=pd.get_dummies(train.drop(['Id','SalePrice'],axis=1))
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)
    xg_reg=xgb.XGBRegressor(objective='reg:linear',colsample_bytree=0.7,learning_rate=0.01,max_depth=3,n_estimators=3460,subsample=0.7,reg_alpha=0.00006,gamma=0,nthread=6,scale_pos_weight=1,seed=27)
    xg_reg.fit(X_train,y_train)
    return benchmark(xg_reg,X_test,y_test)

# %%
SP_Corr=train.corr()['SalePrice']

print(TestDataSet(train))
print(TestDataSet(train.drop(SP_Corr[(SP_Corr<0.3)&(SP_Corr>0)].index.tolist(),axis=1)))
print(TestDataSet(train.drop(SP_Corr[(SP_Corr<0.1)&(SP_Corr>0)].index.tolist(),axis=1)))
print(TestDataSet(train.drop(SP_Corr[(SP_Corr<0.1)&(SP_Corr>-0.1).drop(['Id'])].index.tolist(),axis=1)))
# 可见删掉相关系数大于0且小于0.1的特征，误差会减小
# Out:
# 0.10220848661729656
# 0.1041714692769364
# 0.1018616015313816
# 0.10729170056996896

# %% [markdown]
# 总结：
#
# 1.适当去掉低相关性的列，可能会有所提升
#
# 2.y_train如果是偏态分布，通过函数变换(如log,sqrt,pow等，X值不变)向正态分布适当的拉会降低损失。结果根据变换程度来定,如果程度太大会抹掉与Feature一些相关性，如果程度太小，可能会引来噪声
#
# 3.合理的填充非常重要
#
# 4.数据处理需要经过合理的Scale,将不同的特征单位归一化

# %% [markdown]
# ### 神经网络

# %%
X_train.shape
# Out:
# (1168, 303)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout # Dense是每层神经元数；
                        # Dropout是随机的拿掉网络中的部分神经元，防治过拟合，同时也有集成投票的功能
from keras import metrics # 衡量参数
from keras import backend as K # KFold
from keras.wrappers.scikit_learn import KerasRegressor # 回归器
# Out:
# Using TensorFlow backend.

# %%
DNN_model=Sequential() # 网络的容器，每次训练要create一个新的，不然会接着练之前的网络
DNN_model.add(Dense(110,input_dim=X_train.shape[1],activation='relu')) #input_dim是输入的维度
DNN_model.add(Dense(800,activation='relu'))
#DNN_model.add(Dropout(0.5))  随机失活 50%
DNN_model.add(Dense(100,activation='relu'))
#DNN_model.add(Dropout(0.7))
DNN_model.add(Dense(50,activation='relu'))
DNN_model.add(Dense(1))
DNN_model.compile(optimizer='adam',loss='mean_squared_error')
                     #optimizer是每一轮迭代参数优化的方法
DNN_model.summary() #param是每两层之间的参数个数，训练前后不变，包含偏置项：(Dense(t)+1)*Dense(t+1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 110)               33440
# _________________________________________________________________
# dense_7 (Dense)              (None, 800)               88800
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               80100
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 51
# ...
# Total params: 207,441
# Trainable params: 207,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
DNN_model.fit(X_train,y_train,epochs=350,batch_size=32,verbose=0)
                            # 350个迭代，批梯度下降的batch为32，verbose=0就不会显示出训练过程
benchmark(DNN_model,X_test,y_test)
# Out:
# 0.13272459787919494

# %%
history=DNN_model.fit(X_train,y_train,epochs=350,batch_size=32,verbose=0)

# %%
plt.plot(history.history['loss'],color='#888822')
# 可见训练过程中，损失波动下降

# %%
history=DNN_model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=350,batch_size=32,verbose=0)
# 训练过程中赋值生成的是callbacks，训练完再赋值就是engine了

# %%
plt.plot(history.history['loss'],color='#888822')
plt.plot(history.history['val_loss'],color='#222288')
